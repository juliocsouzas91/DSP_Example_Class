# %%
import numpy as np 
import matplotlib.pylab as plt
import winsound
from scipy.io import wavfile
from scipy.fft import fft, fftfreq
from scipy import signal

# %%
def stop_music():
    winsound.PlaySound(None,0)
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %% [markdown]
# # Criar dois sinais cossenos com freq baixa e alta

# %%
fs = 500000 #(500k)
f_cos1 = 75
f_cos2 = 44000
n = np.arange(0,int(4*fs/f_cos1))
cos1 = .25*np.cos(2*np.pi*f_cos1/fs*n)
gaus = gaussian(int(n.size/2),200,n.size)
cos1 = cos1*gaus
cos2 = np.cos(2*np.pi*f_cos2/fs*n)
cos3 = cos1*cos2

# %%
plt.figure(figsize = (12,12))
plt.subplot(1,3,1)
plt.plot(n,gaus,'b')
plt.axis([0,n.max(),-1,1])
plt.subplot(1,3,2)
plt.plot(n,cos2,'r')
plt.axis([0,500,-1,1])
plt.subplot(1,3,3)
plt.plot(n,cos3,'k')
plt.axis([0,n.max(),-1,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [226], in <cell line: 3>()
#       1 plt.figure(figsize = (12,12))
#       2 plt.subplot(1,3,1)
# ----> 3 plt.plot(n,gaus,'b')
#       4 plt.axis([0,n.max(),-1,1])
#       5 plt.subplot(1,3,2)
#
# File D:\Users\julio\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\Users\julio\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
# ...

# %% [markdown]
# # Análise Espectral

# %%
N = 2**18
win = np.hanning(n.size)
#win = np.ones(n.size)

COS1 = np.abs(fft(win*cos1,N))
COS2 = np.abs(fft(win*cos2,N))
COS3 = np.abs(fft(win*cos3,N))
X_AXIS = fftfreq(N,1/fs)

# %%
plt.figure(figsize=(12,12))
plt.subplot(3,1,1)
plt.plot(X_AXIS,COS1,'ob')
plt.axis([-5000,5000,0,COS1.max()])
plt.subplot(3,1,2)
plt.plot(X_AXIS,COS2,'or')
plt.subplot(3,1,3)
plt.plot(X_AXIS,COS3,'ok')
plt.axis([40000,48000,0,COS3.max()])
# Out:
# (40000.0, 48000.0, 0.0, 833.2807726024663)

# %%
convol =  np.convolve(data[:,0],atraso)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [206], in <cell line: 1>()
# ----> 1 convol =  np.convolve(data[:,0],atraso)
#
# NameError: name 'atraso' is not defined

# %%
data[:,0] = convol[0:-atraso.size+1]

# %%
data2 = data[60*samplerate:63*samplerate,:]

# %%
data3 = np.copy(data2)
data3[:,1] = data3[:,0]/2+data3[:,1]/2
data3[:,0] = data3[:,1]

# %%
wavfile.write("ala.wav", samplerate, data3)

# %%
winsound.PlaySound('ala.wav', winsound.SND_ASYNC)

# %%
N = 2**14
DATA = fft(data2[:,1],N)
FreqSig = fftfreq(N,1/samplerate)

# %%
plt.figure(figsize = (12,12))
plt.plot(FreqSig,np.abs(DATA))
plt.axis([-1000,1000,-1*10**8 ,1*10**8])
# Out:
# (-1000.0, 1000.0, -100000000.0, 100000000.0)

# %%
numtaps = 501
freqwindow = 2*np.array([180])/samplerate
pass_zero = 'lowpass'
coef_b1  = signal.firwin(numtaps,freqwindow,pass_zero = pass_zero, window = "hann") 
coef_a = 1
#coef_b1, coef_a = signal.butter(1, freqwindow)
data3 = signal.lfilter(coef_b1, coef_a, data2/4, axis = 0).astype('int16')
data3[:,0] = signal.filtfilt(coef_b1,coef_a, data2[:,0])
data3[:,1] = signal.filtfilt(coef_b1,coef_a, data2[:,1])
data3 = data3
data3 = data3.astype('int16')

# %%
wavfile.write("ala.wav", samplerate, data3)
winsound.PlaySound('ala.wav', winsound.SND_ASYNC)

# %%
plt.plot(data2[:,1],'b')
plt.plot(data3[:,1],'r')

# %%
coef_b1
# Out:
# array([3.28603015e-05, 9.85809046e-05, 9.85809046e-05, 3.28603015e-05])

# %%
2**16
# Out:
# 65536

# %%
winsound.PlaySound('Final-Fantasy-6-OST-Victory-Fanfare.wav', winsound.SND_ASYNC)

# %%
stop_music()

# %%
samplerate, data = wavfile.read('Final-Fantasy-6-OST-Victory-Fanfare.wav')

# %%
numtaps = 51
freqwindow = 2*np.array([6000])/samplerate
pass_zero = 'lowpass'
coef_b1  = signal.firwin(numtaps,freqwindow,pass_zero = pass_zero, window = "hann") 
coef_a = 1
#coef_b1, coef_a = signal.butter(1, freqwindow)
data = signal.lfilter(coef_b1, coef_a, mod_data, axis = 0).astype('int16')
#data3[:,0] = signal.filtfilt(coef_b1,coef_a, data2[:,0])
#data3[:,1] = signal.filtfilt(coef_b1,coef_a, data2[:,1])
#data3 = data3
#data3 = data3.astype('int16')

# %%
data = data[0:int(4*samplerate),:]
fcos = 14000
portadora = np.cos(2*np.pi*fcos/samplerate*np.arange(0,data.shape[0]))
portadora.shape = (portadora.size,1)
mod_data = data*portadora
mod_data = mod_data.astype('int16')
wavfile.write("ala.wav", samplerate, mod_data)
winsound.PlaySound('ala.wav', winsound.SND_ASYNC)

# %%
N = 2**15
MOD_DATA = fft(np.transpose(mod_data[:,1]),N)
DATA = fft(data[:,1],N)
X_AXIS = fftfreq(N,1/samplerate)

# %%
X_AXIS.max()
# Out:
# 22048.654174804688

# %%
plt.figure(figsize = (12,12))
plt.plot(X_AXIS,np.abs(MOD_DATA),'ob')
plt.plot(X_AXIS,np.abs(DATA),'or')

# %%
mod_data = mod_data*portadora
MOD_DATA = fft(np.transpose(mod_data[:,1]),N)
plt.figure(figsize = (12,12))
plt.plot(X_AXIS,np.abs(MOD_DATA),'ob')

# %%
numtaps = 501
freqwindow = 2*np.array([7000])/samplerate
pass_zero = 'lowpass'
coef_b1  = signal.firwin(numtaps,freqwindow,pass_zero = pass_zero, window = "hann") 
coef_a = 1
#coef_b1, coef_a = signal.butter(1, freqwindow)
data2 = signal.lfilter(coef_b1, coef_a, mod_data, axis = 0).astype('int16')
#data3[:,0] = signal.filtfilt(coef_b1,coef_a, data2[:,0])
#data3[:,1] = signal.filtfilt(coef_b1,coef_a, data2[:,1])
#data3 = data3
#data3 = data3.astype('int16')

# %%
MOD_DATA = fft(np.transpose(data2[:,1]),N)
plt.figure(figsize = (12,12))
plt.plot(X_AXIS,np.abs(MOD_DATA),'ob')

# %%
wavfile.write("ala.wav", samplerate, data2*4)
winsound.PlaySound('ala.wav', winsound.SND_ASYNC)
